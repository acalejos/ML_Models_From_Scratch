# %%
from IPython.display import Image
import sys, os
sys.path.append(os.path.abspath('../'))
import NaiveBayes
import matplotlib.pyplot as plt

# %%
sys.path.append(os.path.abspath('../NaiveBayes'))

# %%
# !ipython ../NaiveBayes/preprocess.py ../CSV/dating-full.csv ../CSV/Produced/dating.csv
# Out:
# Quotes removed from 8316 cells.
# Standardized 5692 cells to lower case.
# Value assigned for male in column gender: 1.
# Value assigned for European/Caucasian-American in column race: 2.
# Value assigned for Latino/Hispanic American in column race_o: 3.
# Value assigned for law in column gender: 121.
# Mean of attractive_important: 22.12.
# Mean of sincere_important: 17.45.
# Mean of intelligence_important: 20.37.
# Mean of funny_important: 17.45.
# Mean of ambition_important: 10.85.
# Mean of shared_interests_important: 11.8.
# Mean of pref_o_attractive: 22.18.
# Mean of pref_o_sincere: 17.48.
# Mean of pref_o_intelligence: 20.34.
# Mean of pref_o_funny: 17.42.
# Mean of pref_o_ambitious: 10.74.
# Mean of pref_o_shared_interests: 11.89.

# %%
# !ipython ../NaiveBayes/norm_data.py ../CSV/Produced/dating.csv

# %%
Image(filename='plots/mean_gender_scored.png')

# %%
# !ipython ../NaiveBayes/norm_data.py ../CSV/Produced/dating.csv

# %%
# !ipython ../NaiveBayes/discretize.py ../CSV/Produced/dating.csv ../CSV/Produced/dating-binned.csv
# Out:
# age: [3710 2932 97 5 0]
# age_o: [3704 2899 136 5 0]
# importance_same_race: [2980 1213 1013 977 561]
# importance_same_religion: [3203 1188 1110 742 501]
# pref_o_attractive: [6739 3 1 1 0]
# pref_o_sincere: [6739 4 1 0 0]
# pref_o_intelligence: [6739 3 1 1 0]
# pref_o_funny: [6741 1 1 1 0]
# pref_o_ambitious: [6739 2 1 1 1]
# pref_o_shared_interests: [6739 2 1 1 1]
# attractive_important: [6738 4 1 1 0]
# sincere_important: [6740 2 1 1 0]
# intelligence_important: [6740 2 1 1 0]
# funny_important: [6740 2 1 1 0]
# ambition_important: [6740 2 1 1 0]
# shared_interests_important: [6740 2 1 1 0]
# attractive: [4122 1462 866 276 18]
# sincere: [3392 2715 487 117 33]
# intelligence: [3190 2286 1049 185 34]
# funny: [3313 3191 221 19 0]
# ambition: [2876 2387 1070 327 84]
# attractive_partner: [2418 2390 948 704 284]
# sincere_partner: [3282 1627 1388 353 94]
# intelligence_partner: [3509 1509 1497 193 36]
# funny_partner: [2600 2296 836 733 279]
# ...

# %%
# !ipython ../NaiveBayes/split.py ../CSV/Produced/dating-binned.csv nb_trainingSet.csv nb_testSet.csv

# %%
# !ipython ../NaiveBayes/nb.py ../CSV/Produced/nb_trainingSet.csv ../CSV/Produced/nb_testSet.csv
# Out:
# Training Accuracy: 77.02
# Testing Accuracy: 74.28

# %%
# !ipython ../NaiveBayes/nb_cv1.py ../CSV/Produced/dating.csv
# Out:
# Bin size: 2
# Training Data Set Accuracy: 74.61
# Test Data Set Accuracy: 70.2
# Bin size: 5
# Training Data Set Accuracy: 77.02
# Test Data Set Accuracy: 74.28
# Bin size: 10
# Training Data Set Accuracy: 78.24
# Test Data Set Accuracy: 74.65
# Bin size: 50
# Training Data Set Accuracy: 78.63
# Test Data Set Accuracy: 74.5
# Bin size: 100
# Training Data Set Accuracy: 78.78
# Test Data Set Accuracy: 73.91
# Bin size: 200
# Training Data Set Accuracy: 78.72
# Test Data Set Accuracy: 74.13

# %%
# !python ../src/Models/NaiveBayes/nb_cv2.py ../CSV/Produced/nb_trainingSet.csv
# Out:
# Traceback (most recent call last):
#   File "../src/Models/NaiveBayes/nb_cv2.py", line 8, in <module>
#     import nb
#   File "C:\Users\AN28450\Documents\ML_Models_From_Scratch\src\Models\NaiveBayes\nb.py", line 5, in <module>
#     import progressBar
# ModuleNotFoundError: No module named 'progressBar'
